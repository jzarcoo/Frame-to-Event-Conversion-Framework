# %%
# !pip install -U pip
# !pip install torch torchvision torchaudio
# !pip install pytorch-lightning
# !pip install spikingjelly
# !pip install tonic
# !pip install h5py
# !pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 33.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 24.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 46.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pytorch-lightning]
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 35.1 MB/s  0:00:00
# ...
#   Created wheel for expelliarmus: filename=expelliarmus-1.1.12-cp312-cp312-linux_x86_64.whl size=56490 sha256=3285fcedbfb11b5401d230881ac959a7b548f229b376c36de29fb5971d589531
#   Stored in directory: /root/.cache/pip/wheels/9a/9e/4b/f96da4dab397e63f90078766122e078e4ba82b2b48e07ee644
# Successfully built expelliarmus
# ...

# %%
# !unzip SFOD.zip
# %cd SFOD
# Out:
# Archive:  SFOD.zip
# replace SFOD/.git/hooks/applypatch-msg.sample? [y]es, [n]o, [A]ll, [N]one, [r]ename: /content/SFOD

# %%
# !touch datasets/__init__.py
# !touch models/__init__.py
# !touch prophesee_utils/__init__.py
# !touch prophesee_utils/io/__init__.py

# %% [markdown]
# # Test NCARS

# %%
# !python classification.py -devices auto -no_train -test -pretrained ncars-epoch=08-val_acc=0.8759.ckpt -model densenet-121_24 -path PropheseeNCARS
# Out:
# 2026-07-01 15:10:32.368518: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Namespace(devices='auto', precision='16-mixed', num_workers=2, b=64, sample_size=100000, T=5, tbin=2, image_shape=(240, 304), dataset='ncars', path='PropheseeNCARS', model='densenet-121_24', bn=True, pretrained='ncars-epoch=08-val_acc=0.8759.ckpt', lr=0.005, epochs=30, train=False, test=True, save_ckpt=False, early_stopping=False, loss_fun='mse', encoding='fre')
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# ...

# %% [markdown]
# # Test DSEC

# %%
# !python classification.py -devices auto -no_train -test -pretrained ncars-epoch=08-val_acc=0.8759.ckpt -model densenet-121_24 -path DSEC
# Out:
# 2026-07-01 15:07:47.879916: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Namespace(devices='auto', precision='16-mixed', num_workers=2, b=64, sample_size=100000, T=5, tbin=2, image_shape=(240, 304), dataset='ncars', path='DSEC', model='densenet-121_24', bn=True, pretrained='ncars-epoch=08-val_acc=0.8759.ckpt', lr=0.005, epochs=30, train=False, test=True, save_ckpt=False, early_stopping=False, loss_fun='mse', encoding='fre')
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# ...

# %% [markdown]
# # Test Framework

# %%
# !python classification.py -devices auto -no_train -test -pretrained ncars-epoch=08-val_acc=0.8759.ckpt -model densenet-121_24 -path Framework
# Out:
# 2026-07-01 15:09:22.186391: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Namespace(devices='auto', precision='16-mixed', num_workers=2, b=64, sample_size=100000, T=5, tbin=2, image_shape=(240, 304), dataset='ncars', path='Framework', model='densenet-121_24', bn=True, pretrained='ncars-epoch=08-val_acc=0.8759.ckpt', lr=0.005, epochs=30, train=False, test=True, save_ckpt=False, early_stopping=False, loss_fun='mse', encoding='fre')
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# ...
