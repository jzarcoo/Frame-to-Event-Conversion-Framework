# %%
# !unzip SFOD.zip
# %cd SFOD
# Out:
# unzip:  cannot find or open SFOD.zip, SFOD.zip.zip or SFOD.zip.ZIP.
# [Errno 2] No such file or directory: 'SFOD'
# /content/SFOD

# %%
# !pip install -U pip
# !pip install torch torchvision torchaudio
# !pip install pytorch-lightning
# !pip install spikingjelly
# !pip install tonic
# !pip install h5py
# !pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 36.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 8.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 13.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pytorch-lightning]
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 34.1 MB/s  0:00:00
# ...
#   Created wheel for expelliarmus: filename=expelliarmus-1.1.12-cp312-cp312-linux_x86_64.whl size=56487 sha256=7651f7c29ca7100dedfefc820cf0379b3c7611b0d63f09ee4505bd80e3166e2d
#   Stored in directory: /root/.cache/pip/wheels/9a/9e/4b/f96da4dab397e63f90078766122e078e4ba82b2b48e07ee644
# Successfully built expelliarmus
# ...

# %%
# !touch datasets/__init__.py
# !touch models/__init__.py
# !touch prophesee_utils/__init__.py
# !touch prophesee_utils/io/__init__.py

# %%
# !python classification.py -devices auto -num_workers 0 -test -save_ckpt -model densenet-121_24 -loss_fun mse -encoding fre -early_stopping
# Out:
# Streaming output truncated to the last 5000 lines.
#                                                                0.035
#                                                                train_loss_epoch:
# Epoch 7/29 ━━━━╺━━━━━━━━━━━━ 58/241 0:00:25 • 0:01:22 2.26it/s v_num: 3.000
#                                                                train_loss_step:
#                                                                0.114
#                                                                train_loss_epoch:
# Epoch 7/29 ━━━━╺━━━━━━━━━━━━ 59/241 0:00:26 • 0:01:21 2.26it/s v_num: 3.000
#                                                                train_loss_step:
#                                                                0.076
#                                                                train_loss_epoch:
# Epoch 7/29 ━━━━╺━━━━━━━━━━━━ 60/241 0:00:26 • 0:01:21 2.26it/s v_num: 3.000
#                                                                train_loss_step:
# ...

# %%
# !ls
# Out:
# ckpt-ncars-densenet-121_24  LICENSE			PropheseeNCARS
# classification_module.py    lightning_logs		prophesee_utils
# classification.py	    models			__pycache__
# datasets		    object_detection_module.py	README.md
# figure.png		    object_detection.py

# %%
# !zip -r ckpt.zip ckpt-ncars-densenet-121_24
# Out:
#   adding: ckpt-ncars-densenet-121_24/ (stored 0%)
#   adding: ckpt-ncars-densenet-121_24/ncars-epoch=04-val_acc=0.8817.ckpt (deflated 10%)
#   adding: ckpt-ncars-densenet-121_24/ncars-epoch=00-val_acc=0.8665.ckpt (deflated 10%)
#   adding: ckpt-ncars-densenet-121_24/ncars-epoch=08-val_acc=0.8759.ckpt (deflated 9%)

# %%
from google.colab import files
files.download("ckpt.zip")

# %%
# !zip -r lightning_logs.zip lightning_logs
# Out:
#   adding: lightning_logs/ (stored 0%)
#   adding: lightning_logs/version_3/ (stored 0%)
#   adding: lightning_logs/version_3/events.out.tfevents.1782828978.58877de48356.13415.0 (deflated 65%)
#   adding: lightning_logs/version_3/hparams.yaml (stored 0%)
#   adding: lightning_logs/version_3/events.out.tfevents.1782830474.58877de48356.13415.1 (deflated 30%)
#   adding: lightning_logs/version_2/ (stored 0%)
#   adding: lightning_logs/version_2/events.out.tfevents.1782828648.58877de48356.11945.0 (deflated 29%)
#   adding: lightning_logs/version_2/hparams.yaml (stored 0%)
#   adding: lightning_logs/version_0/ (stored 0%)
#   adding: lightning_logs/version_0/hparams.yaml (stored 0%)
#   adding: lightning_logs/version_0/events.out.tfevents.1782827966.58877de48356.8929.0 (deflated 29%)
#   adding: lightning_logs/version_1/ (stored 0%)
#   adding: lightning_logs/version_1/hparams.yaml (stored 0%)
# ...

# %%
from google.colab import files
files.download("lightning_logs.zip")

# %%
# !find . -type f -name "*.ckpt"
# Out:
# ./ckpt-ncars-densenet-121_24/ncars-epoch=04-val_acc=0.8817.ckpt
# ./ckpt-ncars-densenet-121_24/ncars-epoch=00-val_acc=0.8665.ckpt
# ./ckpt-ncars-densenet-121_24/ncars-epoch=08-val_acc=0.8759.ckpt

# %%
# !find . -type f \( -name "*.ckpt" -o -name "*.pth" -o -name "*.pt" \)
# Out:
# ./PropheseeNCARS/ncars_test_100_20.0ms_2tbin.pt
# ./PropheseeNCARS/ncars_train_100_20.0ms_2tbin.pt
# ./ckpt-ncars-densenet-121_24/ncars-epoch=04-val_acc=0.8817.ckpt
# ./ckpt-ncars-densenet-121_24/ncars-epoch=00-val_acc=0.8665.ckpt
# ./ckpt-ncars-densenet-121_24/ncars-epoch=08-val_acc=0.8759.ckpt

# %%
# !python --version
# !pip show torch
# !pip show pytorch-lightning
# !pip show torchvision
# Out:
# Python 3.12.13
# Name: torch
# Version: 2.11.0+cu128
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org
# Author:
# Author-email: PyTorch Team <packages@pytorch.org>
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: cuda-bindings, cuda-toolkit, filelock, fsspec, jinja2, networkx, nvidia-cudnn-cu12, nvidia-cusparselt-cu12, nvidia-nccl-cu12, nvidia-nvshmem-cu12, setuptools, sympy, triton, typing-extensions
# Required-by: accelerate, fastai, peft, pytorch-lightning, sentence-transformers, spikingjelly, timm, torchdata, torchmetrics, torchvision
# Name: pytorch-lightning
# Version: 2.6.5
# Summary: PyTorch Lightning is the lightweight PyTorch wrapper for ML researchers. Scale your models. Write less boilerplate.
# Home-page: https://github.com/Lightning-AI/lightning
# Author: Lightning AI et al.
# Author-email: developer@lightning.ai
# License: Apache-2.0
# ...

# %%
# !pip freeze > requirements.txt

# %%
# %cd /content
# !zip -r SFOD.zip SFOD
from google.colab import files
files.download("SFOD.zip")
# Out:
# Streaming output truncated to the last 5000 lines.
# updating: SFOD/PropheseeNCARS/test/background/obj_003380_td.dat (deflated 38%)
# updating: SFOD/PropheseeNCARS/test/background/obj_003376_td.dat (deflated 37%)
# updating: SFOD/PropheseeNCARS/test/background/obj_003371_td.dat (deflated 41%)
# updating: SFOD/PropheseeNCARS/test/background/obj_003366_td.dat (deflated 42%)
# updating: SFOD/PropheseeNCARS/test/background/obj_003365_td.dat (deflated 42%)
# updating: SFOD/PropheseeNCARS/test/background/obj_003362_td.dat (deflated 40%)
# updating: SFOD/PropheseeNCARS/test/background/obj_003360_td.dat (deflated 44%)
# updating: SFOD/PropheseeNCARS/test/background/obj_003351_td.dat (deflated 41%)
# updating: SFOD/PropheseeNCARS/test/background/obj_003340_td.dat (deflated 39%)
# updating: SFOD/PropheseeNCARS/test/background/obj_003253_td.dat (deflated 38%)
# updating: SFOD/PropheseeNCARS/test/background/obj_003245_td.dat (deflated 39%)
# ...
