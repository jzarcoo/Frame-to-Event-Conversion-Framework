# %%
# !git clone https://github.com/KirillHit/twl_spike_yolo.git
# Out:
# Cloning into 'twl_spike_yolo'...
# remote: Enumerating objects: 702, done.
# remote: Counting objects: 100% (702/702), done.
# remote: Compressing objects: 100% (294/294), done.
# remote: Total 702 (delta 372), reused 668 (delta 347), pack-reused 0 (from 0)
# Receiving objects: 100% (702/702), 4.51 MiB | 7.60 MiB/s, done.
# Resolving deltas: 100% (372/372), done.

# %%
# %cd twl_spike_yolo
# Out:
# /content/twl_spike_yolo

# %%
# !pip install -U pip

# !pip install \
torch==2.7.0 \
torchvision==0.22.0 \
torchaudio==2.7.0 \
torchdata==0.11.0 \
lightning==2.5.1.post0 \
torchmetrics==1.7.2 \
hydra-core==1.3.2 \
opencv-python \
matplotlib \
matplotlib-inline \
seaborn \
h5py \
numba \
pandas \
pyyaml \
tqdm \
tensorboardx \
jsonargparse \
omegaconf \
norse \
nirtorch \
nir \
plotly \
pycocotools \
faster-coco-eval \
safetensors \
huggingface_hub \
bitsandbytes \
neptune \
git+https://github.com/KirillHit/dsec-det
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 38.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#   Cloning https://github.com/KirillHit/dsec-det to /tmp/pip-req-build-wk5_krye
#   Running command git clone --filter=blob:none --quiet https://github.com/KirillHit/dsec-det /tmp/pip-req-build-wk5_krye
#   Resolved https://github.com/KirillHit/dsec-det to commit 77be6b1412f185d3f01bac34fe958a90c0808ac0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.3 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.0/865.0 MB 15.1 MB/s  0:00:23
# ...

# %%
# !pip install -U "jsonargparse[signatures]>=4.27.7"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 13.4 MB/s  0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/data.zip"
# Out:
# Archive:  /content/drive/MyDrive/data.zip
#    creating: data/
#    creating: data/dsec/
#    creating: data/dsec/test/
#    creating: data/dsec/test/zurich_city_13_a/
#    creating: data/dsec/test/zurich_city_13_a/object_detections/
#    creating: data/dsec/test/zurich_city_13_a/object_detections/left/
#   inflating: data/dsec/test/zurich_city_13_a/object_detections/left/tracks.npy
#    creating: data/dsec/test/zurich_city_13_a/images/
#    creating: data/dsec/test/zurich_city_13_a/images/left/
#    creating: data/dsec/test/zurich_city_13_a/images/left/distorted/
#   inflating: data/dsec/test/zurich_city_13_a/images/left/distorted/000289.png
#   inflating: data/dsec/test/zurich_city_13_a/images/left/distorted/000002.png
#   inflating: data/dsec/test/zurich_city_13_a/images/left/distorted/000272.png
#   inflating: data/dsec/test/zurich_city_13_a/images/left/distorted/000262.png
#   inflating: data/dsec/test/zurich_city_13_a/images/left/distorted/000299.png
# ...

# %%
# !pip install -U hdf5plugin
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 MB 34.0 MB/s  0:00:01
# ...

# %% [markdown]
# en `utils/dataset_dsec.py` poner `import hdf5plugin`

# %% [markdown]
# en `config/yolo8l_dsec_only_events.yaml`
# ```sh
#     plotter:
#       class_path: utils.Plotter
#       init_args:
#         threshold: 0.0
#         show_video: false
#         save_video: true
# ```

# %% [markdown]
# # v2e

# %% [markdown]
# Replace `data/dsec/test/zurich_city_13_a/events/left/events.h5`

# %% [markdown]
# ## Predict

# %% [markdown]
# ```py
# def _preprocess_events(self, src: np.ndarray) -> torch.Tensor:
#         if len(src["t"]) == 0:
#           return events
# ```

# %%
# !python main.py predict --config config/yolo8l_dsec_only_events.yaml
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/_cxx_pytree.py:243: UserWarning: PyTree type <class 'norse.torch.utils.pytree.LIFParameters'> is a subclass of `collections.namedtuple`, which is already registered in the global namespace. Override it with custom flatten/unflatten functions in namespace 'torch'.
#   optree.register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/torch/utils/_cxx_pytree.py:243: UserWarning: PyTree type <class 'norse.torch.utils.pytree.LIFBoxParameters'> is a subclass of `collections.namedtuple`, which is already registered in the global namespace. Override it with custom flatten/unflatten functions in namespace 'torch'.
#   optree.register_pytree_node(
# 2026-07-15 17:42:43.058488: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !zip -r log_v2e.zip log/
# !zip -r lightning_logs_v2e.zip lightning_logs/
# Out:
# updating: log/ (stored 0%)
# updating: log/out302.gif (deflated 1%)
# updating: log/out238.gif (deflated 1%)
# updating: log/out107.gif (deflated 1%)
# updating: log/out117.gif (deflated 1%)
# updating: log/out275.gif (deflated 1%)
# updating: log/out249.gif (deflated 1%)
# updating: log/out218.gif (deflated 1%)
# updating: log/out207.gif (deflated 1%)
# updating: log/out124.gif (deflated 0%)
# updating: log/out146.gif (deflated 1%)
# updating: log/out225.gif (deflated 1%)
# updating: log/out89.gif (deflated 1%)
# updating: log/out71.gif (deflated 1%)
# updating: log/out34.gif (deflated 1%)
# updating: log/out376.gif (deflated 1%)
# updating: log/out255.gif (deflated 1%)
# updating: log/out199.gif (deflated 1%)
# updating: log/out87.gif (deflated 1%)
# updating: log/out57.gif (deflated 1%)
# updating: log/out264.gif (deflated 1%)
# updating: log/out44.gif (deflated 0%)
# updating: log/out82.gif (deflated 1%)
# updating: log/out248.gif (deflated 1%)
# ...

# %%
from google.colab import files
files.download("log_v2e.zip")
files.download("lightning_logs_v2e.zip")

# %%
# !rm -rf log
# !rm -rf lightning_logs

# %% [markdown]
# ## Test

# %%
# !python main.py test --config config/yolo8l_dsec_only_events.yaml
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/_cxx_pytree.py:243: UserWarning: PyTree type <class 'norse.torch.utils.pytree.LIFParameters'> is a subclass of `collections.namedtuple`, which is already registered in the global namespace. Override it with custom flatten/unflatten functions in namespace 'torch'.
#   optree.register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/torch/utils/_cxx_pytree.py:243: UserWarning: PyTree type <class 'norse.torch.utils.pytree.LIFBoxParameters'> is a subclass of `collections.namedtuple`, which is already registered in the global namespace. Override it with custom flatten/unflatten functions in namespace 'torch'.
#   optree.register_pytree_node(
# 2026-07-15 18:09:33.604424: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !zip -r lightning_logs_v2e_test.zip lightning_logs/
# Out:
#   adding: lightning_logs/ (stored 0%)
#   adding: lightning_logs/version_0/ (stored 0%)
#   adding: lightning_logs/version_0/events.out.tfevents.1784138979.8be4b90783ae.15118.0 (deflated 41%)
#   adding: lightning_logs/version_0/hparams.yaml (deflated 45%)
#   adding: lightning_logs/version_0/config.yaml (deflated 61%)

# %%
from google.colab import files

files.download("lightning_logs_v2e_test.zip")

# %%
# !rm -rf lightning_logs
# !rm -f lightning_logs.zip

# %% [markdown]
# # DSEC

# %% [markdown]
# Replace `data/dsec/test/zurich_city_13_a/events/left/events.h5`

# %% [markdown]
# ## Predict

# %%
# !python main.py predict --config config/yolo8l_dsec_only_events.yaml
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/_cxx_pytree.py:243: UserWarning: PyTree type <class 'norse.torch.utils.pytree.LIFParameters'> is a subclass of `collections.namedtuple`, which is already registered in the global namespace. Override it with custom flatten/unflatten functions in namespace 'torch'.
#   optree.register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/torch/utils/_cxx_pytree.py:243: UserWarning: PyTree type <class 'norse.torch.utils.pytree.LIFBoxParameters'> is a subclass of `collections.namedtuple`, which is already registered in the global namespace. Override it with custom flatten/unflatten functions in namespace 'torch'.
#   optree.register_pytree_node(
# 2026-07-11 12:12:20.874902: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !zip -r log.zip log/
# !zip -r lightning_logs.zip lightning_logs/
# Out:
#   adding: log/ (stored 0%)
#   adding: log/out38.gif (deflated 1%)
#   adding: log/out310.gif (deflated 1%)
#   adding: log/out132.gif (deflated 1%)
#   adding: log/out7.gif (deflated 0%)
#   adding: log/out171.gif (deflated 1%)
#   adding: log/out269.gif (deflated 1%)
#   adding: log/out112.gif (deflated 1%)
#   adding: log/out210.gif (deflated 0%)
#   adding: log/out75.gif (deflated 1%)
#   adding: log/out158.gif (deflated 1%)
#   adding: log/out297.gif (deflated 1%)
#   adding: log/out110.gif (deflated 1%)
#   adding: log/out313.gif (deflated 1%)
#   adding: log/out351.gif (deflated 1%)
#   adding: log/out334.gif (deflated 0%)
#   adding: log/out25.gif (deflated 1%)
#   adding: log/out232.gif (deflated 1%)
#   adding: log/out104.gif (deflated 0%)
#   adding: log/out288.gif (deflated 1%)
#   adding: log/out149.gif (deflated 1%)
#   adding: log/out348.gif (deflated 1%)
#   adding: log/out234.gif (deflated 1%)
#   adding: log/out125.gif (deflated 0%)
# ...

# %%
from google.colab import files
files.download("log.zip")
files.download("lightning_logs.zip")

# %%
# !rm -rf log
# !rm -rf lightning_logs
# !rm -f log.zip
# !rm -f lightning_logs.zip

# %% [markdown]
# ## Test

# %%
# !python main.py test --config config/yolo8l_dsec_only_events.yaml
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/_cxx_pytree.py:243: UserWarning: PyTree type <class 'norse.torch.utils.pytree.LIFParameters'> is a subclass of `collections.namedtuple`, which is already registered in the global namespace. Override it with custom flatten/unflatten functions in namespace 'torch'.
#   optree.register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/torch/utils/_cxx_pytree.py:243: UserWarning: PyTree type <class 'norse.torch.utils.pytree.LIFBoxParameters'> is a subclass of `collections.namedtuple`, which is already registered in the global namespace. Override it with custom flatten/unflatten functions in namespace 'torch'.
#   optree.register_pytree_node(
# 2026-07-11 13:13:51.350952: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !ls
# Out:
# CITATION.bib  data  environment.yml  lightning_logs  model	scripts
# config	      docs  LICENSE	     main.py	     README.md	utils

# %%
# !zip -r lightning_logs.zip lightning_logs/
# Out:
# updating: lightning_logs/ (stored 0%)
# updating: lightning_logs/version_0/ (stored 0%)
# updating: lightning_logs/version_0/events.out.tfevents.1783775637.ad91141e19c3.19940.0 (deflated 41%)
# updating: lightning_logs/version_0/config.yaml (deflated 61%)
# updating: lightning_logs/version_0/hparams.yaml (deflated 45%)

# %%
from google.colab import files
files.download("lightning_logs.zip")

# %%
# !rm -rf lightning_logs
# !rm -f lightning_logs.zip

# %% [markdown]
# # Framework

# %% [markdown]
# Replace `data/dsec/test/zurich_city_13_a/events/left/events.h5`

# %% [markdown]
# ## Predict

# %% [markdown]
# ```py
# def _preprocess_events(self, src: np.ndarray) -> torch.Tensor:
#         if len(src["t"]) == 0:
#           return events
# ```

# %%
# !python main.py predict --config config/yolo8l_dsec_only_events.yaml
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/_cxx_pytree.py:243: UserWarning: PyTree type <class 'norse.torch.utils.pytree.LIFParameters'> is a subclass of `collections.namedtuple`, which is already registered in the global namespace. Override it with custom flatten/unflatten functions in namespace 'torch'.
#   optree.register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/torch/utils/_cxx_pytree.py:243: UserWarning: PyTree type <class 'norse.torch.utils.pytree.LIFBoxParameters'> is a subclass of `collections.namedtuple`, which is already registered in the global namespace. Override it with custom flatten/unflatten functions in namespace 'torch'.
#   optree.register_pytree_node(
# 2026-07-11 16:29:17.406279: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !zip -r log.zip log/
# !zip -r lightning_logs.zip lightning_logs/
# Out:
#   adding: log/ (stored 0%)
#   adding: log/out38.gif (deflated 1%)
#   adding: log/out310.gif (deflated 1%)
#   adding: log/out132.gif (deflated 1%)
#   adding: log/out7.gif (deflated 0%)
#   adding: log/out171.gif (deflated 1%)
#   adding: log/out269.gif (deflated 1%)
#   adding: log/out112.gif (deflated 1%)
#   adding: log/out210.gif (deflated 0%)
#   adding: log/out75.gif (deflated 1%)
#   adding: log/out158.gif (deflated 1%)
#   adding: log/out297.gif (deflated 1%)
#   adding: log/out110.gif (deflated 1%)
#   adding: log/out313.gif (deflated 1%)
#   adding: log/out351.gif (deflated 1%)
#   adding: log/out334.gif (deflated 0%)
#   adding: log/out25.gif (deflated 0%)
#   adding: log/out232.gif (deflated 1%)
#   adding: log/out104.gif (deflated 0%)
#   adding: log/out288.gif (deflated 1%)
#   adding: log/out149.gif (deflated 1%)
#   adding: log/out348.gif (deflated 0%)
#   adding: log/out234.gif (deflated 1%)
#   adding: log/out125.gif (deflated 0%)
# ...

# %%
from google.colab import files
files.download("log.zip")
files.download("lightning_logs.zip")

# %%
# !rm -rf log
# !rm -rf lightning_logs
# !rm -f log.zip
# !rm -f lightning_logs.zip

# %% [markdown]
# ## Test

# %%
# !python main.py test --config config/yolo8l_dsec_only_events.yaml
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/_cxx_pytree.py:243: UserWarning: PyTree type <class 'norse.torch.utils.pytree.LIFParameters'> is a subclass of `collections.namedtuple`, which is already registered in the global namespace. Override it with custom flatten/unflatten functions in namespace 'torch'.
#   optree.register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/torch/utils/_cxx_pytree.py:243: UserWarning: PyTree type <class 'norse.torch.utils.pytree.LIFBoxParameters'> is a subclass of `collections.namedtuple`, which is already registered in the global namespace. Override it with custom flatten/unflatten functions in namespace 'torch'.
#   optree.register_pytree_node(
# 2026-07-11 16:10:58.702051: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !zip -r lightning_logs.zip lightning_logs/
# Out:
#   adding: lightning_logs/ (stored 0%)
#   adding: lightning_logs/version_0/ (stored 0%)
#   adding: lightning_logs/version_0/events.out.tfevents.1783786264.3e7029b58f67.30912.0 (deflated 42%)
#   adding: lightning_logs/version_0/config.yaml (deflated 61%)
#   adding: lightning_logs/version_0/hparams.yaml (deflated 45%)

# %%
from google.colab import files

files.download("lightning_logs.zip")

# %%
# !rm -rf lightning_logs
# !rm -f lightning_logs.zip

# %%
# !ls
